# %% [markdown]
# <a href="https://colab.research.google.com/github/Supieiei/PythonDataViz2026/blob/main/Hw1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #น.ส.สุพิชญา ผ่องสนาม

# %%
print('673020266-3')
# Out:
# 673020266-3
